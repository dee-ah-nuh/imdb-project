# %%
import pandas as pd
import numpy as np

# %%
titleakas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
titlebasics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
ratings.replace({'\\N': np.nan})
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1901
# 1        tt0000002            5.9       254
# 2        tt0000003            6.5      1694
# 3        tt0000004            5.7       166
# 4        tt0000005            6.2      2511
# ...            ...            ...       ...
# 1254581  tt9916690            6.5         6
# 1254582  tt9916720            5.2       237
# 1254583  tt9916730            8.4         6
# 1254584  tt9916766            6.8        21
# 1254585  tt9916778            7.2        35
#
# [1254586 rows x 3 columns]

# %%
instructionsForRatings='Replace "/N" with np.nan (if any)'
ratings.to_csv('Data/ratings.csv')

# %%
title = pd.read_csv(titlebasics_url, sep="\t", low_memory=False)

# %%
title.replace({'\\N': np.nan})
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9101802  tt9916848  tvEpisode              Episode #3.17
# 9101803  tt9916850  tvEpisode              Episode #3.19
# 9101804  tt9916852  tvEpisode              Episode #3.20
# 9101805  tt9916856      short                   The Wind
# 9101806  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9101802              Episode #3.17       0      2010     NaN            NaN
# 9101803              Episode #3.19       0      2010     NaN            NaN
# 9101804              Episode #3.20       0      2010     NaN            NaN
# 9101805                   The Wind       0      2015     NaN             27
# 9101806  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9101802         Action,Drama,Family
# 9101803         Action,Drama,Family
# 9101804         Action,Drama,Family
# 9101805                       Short
# 9101806  Adventure,Animation,Comedy
#
# [9101807 rows x 9 columns]

# %%
instructionsfortitle= '''
Replace '/N' with np.nan  
Eliminate movies that are null for runtimeMinutes 
Eliminate movies that are null for genre 
keep only titleType==Movie 
keep startYear 2000-2022 
Eliminate movies that include 'Documentary' in genre (see tip below)"
'''
title = title.dropna(subset=['genres'])
isDocumentary = title['genres'].str.contains('documentary', case=False)
title = title[~isDocumentary]
titleTypeMovie = title["titleType"]=='Movie'
title = title[titleTypeMovie]
title = title[title['genres'].dropna()]
title.to_csv("Data/title.csv")

# %%
alternateTitles = pd.read_csv(titleakas_url, sep='\t', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 alternateTitles = pd.read_csv(titleakas_url, sep='\t', low_memory=False)
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     227         data = _concatenate_chunks(chunks)
#     229     else:
# --> 230         data = self._reader.read(nrows)
#     231 except StopIteration:
#     232     if self._first_chunk:
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\_libs\parsers.pyx:787, in pandas._libs.parsers.TextReader.read()
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\_libs\parsers.pyx:876, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\.conda\envs\dojo-env\lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: out of memory

# %%
alternateTitles.replace({'\\N': np.nan})

# %%
#df[(df['B']=='Blue') & (df['C']=='Green')]
alternateTitles = alternateTitles[(alternateTitles['region']=="US")]

# %%
alternateTitles.head()

# %%
alternateTitle.to_csv('Data/alternateTitles.csv')
